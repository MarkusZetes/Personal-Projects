# %% [markdown]
# # Visual analysis of the sales performance of a shipping company

# %% [markdown]
# ## In this project I'm going to present how I went about analyzing the sales performance of a company only using Tableau. I will present each graph step by step and finally I will present the dashboard as a whole (actionable, interactive dashboard)

# %% [markdown]
# ## Of course you can follow along on the actual work, on my public Tableau link:
# https://public.tableau.com/app/profile/markus.zetes/viz/FinalAssignmentWorkearlyDashboard/F_ADashboard

# %% [markdown]
# **I imported first the data here, so I can you can have a look at it properly. Basically there are a lot of discrete data fields and a few continuous ones. I will print out the first 20 lines of the dataset, so you can take a look at it**

# %%
import pandas as pd

# %%
data = pd.read_csv('Shipping Comp.csv', encoding='windows-1252')

# %%
data.head(20)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2018-152156   11/8/2018  11/11/2018    Second Class
# 1        2  CA-2018-152156   11/8/2018  11/11/2018    Second Class
# 2        3  CA-2018-138688   6/12/2018   6/16/2018    Second Class
# 3        4  US-2017-108966  10/11/2017  10/18/2017  Standard Class
# 4        5  US-2017-108966  10/11/2017  10/18/2017  Standard Class
# 5        6  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 6        7  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 7        8  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 8        9  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 9       10  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 10      11  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 11      12  CA-2016-115812    6/9/2016   6/14/2016  Standard Class
# 12      13  CA-2019-114412   4/15/2019   4/20/2019  Standard Class
# ...

# %% [markdown]
# **The first task that I want to perform on this dataset is to create a line char to showcase the profit of the company in terms of category and subcategory. Basically I want to see what kind of items bring in the best profit for the company, and if there are any that actually loose money for the company: Let's explore!**

# %% [markdown]
# ![Tableau%20TASK%201.png](attachment:Tableau%20TASK%201.png)

# %% [markdown]
# - First thing that stands out is that the 'Technology' category is the most profitable one, and it actually makes a lot of sense, since all companies try to exapand technologically as much as they can.
# - Moreover, this category is the only one that doesn't have items that loose them money. Generally speaking, each category brings them profit, but the furniture is the weakest performing one.
# - We can clearly see that this company loses the most amount of money on tables, so they need to look into it and sort out why.
# - In rest, the data is pretty much self explanatory, the user can choose the date filter, if they want to see the profit by categories in a specific year, but in the picture above the numbers are just averages for all avaiable years

# %% [markdown]
# **Next order of action that is interesting for me, is to represent quantitavely and qualitatively the profits made by each mode of shipping. Basically, which mode a shipping produced the what kind of profit. For this categorical values it seemed right to use a standard piechart:**

# %% [markdown]
# ![Tableau%20TASK%202.png](attachment:Tableau%20TASK%202.png)

# %% [markdown]
# - First of all, I decided not to annotate the pie-slices, because it looks much better like this in the final dashboard
# - Intuitively, most customers choose standard class when something needs to be delivered, in order not to overpay (myself included), so it's only logical that that class brings in the most profit.
# - Only 5% of the generated profit is brought in by same-day delivery, which honestly performs very bad, and it's understandable, since companies tend to ask for pretty heavy taxes for a 'same-day' delivery
# - First-Class and Second-Class are pretty evenly distributed, so maybe the pay-fair is not so big between the two
# - Again, the user can acces this information fitered by different years, by request also by months, days, etc. (I used this filter all along my worksheets, so I won't be reffering to it anymore)

# %% [markdown]
# **In the next part I chose to display the highest selling cities for this company, and since it is an American based company, al cities are from the USA. I chose to display this information as a bubble-chart, since in all my other projects I disclosed this kind of information as a map, but for now I wanted some change, and this also works really well**

# %% [markdown]
# ![Tableau%20TASK%203-3.png](attachment:Tableau%20TASK%203-3.png)

# %% [markdown]
# - We can see that the most sales are borugh in by the likes of New York City, Phily, LA and Seattle. New York is the clear leader of this hierarchy with over 250k sales.
# - However, it's notable from how many places there are incoming shipping requests. Each bubble on the represent a selling point, having a white color meaning a very small number of sales, and gradually evolving towards dark red (highest number of sales)

# %% [markdown]
# **Now since we know the highest seling few cities, I would like to filter out the top 5 selling ones, and actually see what numbers they put out throughout the years, with their high and low points**

# %% [markdown]
# ![Tableau%20TASK%204.png](attachment:Tableau%20TASK%204.png)

# %% [markdown]
# - For this task it seemed rather fitting to use a temporal line chart
# - The numbers for New York are not that surprising, with a few highs and lows, however, we can see some powerful ascending trends in Philadelphia, San Francisco and a literal explosion of sales from 2018 to 2019 in Seattle
# - Unfortunatelly, Los Angeles seems to be going down in sales, and can be shortly outsaled by the likes of San Francisco and Philadeplhia

# %% [markdown]
# **In the next task I want to incorporate the 'Segment' column, which indicates who (as an entity) placed the shipment, from which category did they order and finally how did they want their goods to be delivered**

# %% [markdown]
# ![Tableau%20TASK%205.png](attachment:Tableau%20TASK%205.png)

# %% [markdown]
# - There is not a great deal of distinct information from this graphs, however, we can see that 'consumers' so basically individuals produce the most sales for the company.
# - The distribution throughout the category and shipment mode is quite frankly similar in all the cases, again, the standard class being the most preffered one

# %% [markdown]
# **The last piece of analysis I want to do is to establish if a relationship between number of orders and a certain discount exists**

# %% [markdown]
# ![Tableau%20TASK%206.png](attachment:Tableau%20TASK%206.png)

# %% [markdown]
# - On the left side of the table the discounted amount (the sum of it) is presented and it can be easily seen, that the entity with the highest discounts (Binders), produced the highest amount of orders
# - So it is actually a good ideea to offer some discounts, and as it can be seen at 'Paper' or 'Furnishing' Sub-Categories, the discount shouldn't even be that high, and people are still more likely to order that good

# %% [markdown]
# **When preparing a dashboard, the best praxis for it is not to be overcrowded with data, so I think that for this performance analysis the above presented graphs are enough for a good insight and an elegant dashboard**

# %% [markdown]
# ![Tableau%20TASK%207.png](attachment:Tableau%20TASK%207.png)

# %% [markdown]
# - In my opinion, this is a clean dashboard, that brings meaningful and important insights about the company
# - The dashboard is interactive, with lots of actions, that can be checked out on this link: https://public.tableau.com/app/profile/markus.zetes/viz/FinalAssignmentWorkearlyDashboard/F_ADashboard
# - The dashboard can be further edited for the exact liking of the user (add filters, etc.)

# %% [markdown]
# **Finally, just to showcase this ability of Tableau, I also wrote some storypoints in the dashboard presentation**

# %% [markdown]
# ![Tableau%20TASK%208.png](attachment:Tableau%20TASK%208.png)

# %% [markdown]
# - We can see that clicking on a storypoint, highlights the data about which is being spoken in that story point. For example, here I was speaking about the performance of New York, aka. the best performer of this comapny

# %% [markdown]
# ## This short story/projects ends here, I hoped you enjoyed this colorful analysis, feel free to check out this Viz on my Tableau Public Page, and check out other graphs that I have there !
